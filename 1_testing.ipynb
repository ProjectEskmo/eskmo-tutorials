# %%
from eskmo import api

api.init()

api.testing()
# Out:
# %ZP INFO  2024-07-31 11:51:19.695593 | Main | 30308 |[ eskmo version: 0.0.65 ]
# %PU INFO  2024-07-31 11:51:19.750471 | Main | 30308 |The ZMQ Listener initiates on 'tcp://*:63377'.
# %JU INFO  2024-07-31 11:51:19.801447 | Main | 30308 |The ZMQ socket has been initialized at 'tcp://localhost:63377'.
# %AP INFO  2024-07-31 11:51:19.852691 | Main | 30308 |API register: ProcessID: 30308 (id=__TESTING__)
# %HU INFO  2024-07-31 11:51:19.903822 | Main | 30308 |Creating 1 'SkcomRunner' runner(s).
# %XU INFO  2024-07-31 11:51:20.454470 | API  | 35328 |The API 'SKCOM_c78a95' has started successfully.
# %FU INFO  2024-07-31 11:51:20.459634 | API  | 35328 |The ZMQ socket has been initialized at 'tcp://localhost:63377'.
# %JU INFO  2024-07-31 11:51:20.461727 | API  | 35328 |The ZMQ Listener initiates on 'tcp://*:63382'.
# %CU INFO  2024-07-31 11:51:20.610739 | Main | 30308 |The ZMQ socket has been initialized at 'tcp://localhost:63382 on port '63382'.
# {'檢測項目': [('啟動多進程', '成功'),
# ...
